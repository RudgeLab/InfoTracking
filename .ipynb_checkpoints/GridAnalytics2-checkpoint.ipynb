# %%
import PickleVelocity as PV
import EM as EM
import plotting as pt

# %%
fname = "/Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-%04d0.png"
startframe = 40
nframes = 20
dt = 1 #There's a bit of trouble with this
gridfactor = 32 #pixels per grid
gridPV,gridstuff,velpos,imgs = PV.main(fname,startframe,nframes,dt,gridfactor,forwards = False, GridMethod = 1)
# Out:
# worldsize =  250.0
# imagesize =  1181
# resizing factor =  4.724
# Skipped 226 ids, which should match this number: -113
# Skipped 234 ids, which should match this number: -117
# Skipped 274 ids, which should match this number: -137
# Skipped 246 ids, which should match this number: -123
# Skipped 198 ids, which should match this number: -99
# Skipped 164 ids, which should match this number: -82
# Skipped 216 ids, which should match this number: -108
# Skipped 210 ids, which should match this number: -105
# Skipped 218 ids, which should match this number: -109
# Skipped 168 ids, which should match this number: -84
# Skipped 144 ids, which should match this number: -72
# Skipped 184 ids, which should match this number: -92
# Skipped 164 ids, which should match this number: -82
# Skipped 162 ids, which should match this number: -81
# Skipped 152 ids, which should match this number: -76
# Skipped 118 ids, which should match this number: -59
# Skipped 144 ids, which should match this number: -72
# Skipped 160 ids, which should match this number: -80
# Skipped 98 ids, which should match this number: -49
# Done calculating velocities
# Grid dimensions:  36 36
# There are 0 cells in the gaps between grid cells in step 0
# There are 4 cells in the gaps between grid cells in step 1
# There are 4 cells in the gaps between grid cells in step 2
# There are 3 cells in the gaps between grid cells in step 3
# There are 2 cells in the gaps between grid cells in step 4
# There are 1 cells in the gaps between grid cells in step 5
# There are 2 cells in the gaps between grid cells in step 6
# There are 2 cells in the gaps between grid cells in step 7
# There are 3 cells in the gaps between grid cells in step 8
# There are 0 cells in the gaps between grid cells in step 9
# There are 0 cells in the gaps between grid cells in step 10
# There are 1 cells in the gaps between grid cells in step 11
# There are 0 cells in the gaps between grid cells in step 12
# There are 0 cells in the gaps between grid cells in step 13
# There are 0 cells in the gaps between grid cells in step 14
# There are 0 cells in the gaps between grid cells in step 15
# There are 0 cells in the gaps between grid cells in step 16
# There are 0 cells in the gaps between grid cells in step 17
# There are 0 cells in the gaps between grid cells in step 18
# Done

# %%
gridEM = EM.main(fname,startframe,nframes,dt,gridfactor, forwards = False, GridMethod = 1) #Grid Method 2 not ready yet
# Out:
# Image dimensions:  1181 1181
# Grid dimensions:  36 36
# Image intensity range:
# 0.0 1.0
# 0.0 1.0
# ------------ Step 0 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00600.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00590.png
# vel  -7 1
# vel  -7 -7
# vel  -7 -1
# vel  -7 4
# vel  -5 1
# vel  -7 -3
# vel  3 3
# vel  4 0
# vel  3 0
# vel  5 -1
# vel  4 -1
# vel  3 -1
# vel  -7 6
# vel  -7 3
# vel  -7 -7
# vel  3 1
# vel  2 1
# vel  2 1
# vel  2 0
# vel  1 0
# vel  2 0
# vel  2 -2
# vel  2 -3
# vel  4 -2
# vel  -3 4
# vel  -7 -7
# vel  2 2
# vel  2 2
# vel  2 4
# vel  2 0
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -2
# vel  3 -4
# vel  -2 5
# vel  -5 -7
# vel  6 4
# vel  1 3
# vel  1 1
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  0 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -2
# vel  -7 7
# vel  -7 -7
# vel  0 4
# vel  1 2
# vel  1 1
# vel  1 1
# vel  0 0
# vel  0 0
# vel  1 5
# vel  0 0
# vel  1 -1
# vel  0 -1
# vel  0 -2
# vel  1 -3
# vel  2 -3
# vel  -6 6
# vel  0 4
# vel  -1 3
# vel  1 1
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  0 -2
# vel  -1 -4
# vel  0 -5
# vel  -2 -1
# vel  -2 4
# vel  0 2
# vel  0 1
# vel  6 -2
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  2 -5
# vel  0 -1
# vel  1 -1
# vel  -1 -5
# vel  6 6
# vel  6 -7
# vel  -5 4
# vel  0 2
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  -1 0
# vel  0 0
# vel  0 -1
# vel  -1 -1
# vel  -1 -1
# vel  0 -2
# vel  0 -7
# vel  0 7
# vel  0 -5
# vel  -2 3
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  0 1
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -4 -5
# vel  0 -2
# vel  -2 -4
# vel  -1 6
# vel  -4 3
# vel  -2 2
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  -1 1
# vel  2 0
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  -2 -2
# vel  -1 -2
# vel  -2 -6
# vel  1 5
# vel  5 -6
# vel  -4 4
# vel  -1 2
# vel  4 5
# vel  -2 0
# vel  -1 0
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -2 -2
# vel  -2 -2
# vel  -3 -4
# vel  5 6
# vel  7 -7
# vel  -4 4
# vel  -4 2
# vel  -2 0
# vel  -1 7
# vel  -2 0
# vel  -1 -1
# vel  -3 -1
# vel  -7 -6
# vel  -5 -3
# vel  7 6
# vel  6 -2
# vel  7 -7
# vel  -5 1
# vel  -7 3
# vel  -5 -1
# vel  -4 0
# vel  -4 -1
# vel  6 6
# vel  5 0
# vel  6 -1
# vel  4 -2
# vel  7 -1
# vel  6 5
# ------------ Step 1 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00590.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00580.png
# vel  -5 -1
# vel  4 3
# vel  4 0
# vel  4 0
# vel  4 0
# vel  4 -3
# vel  6 -2
# vel  -5 0
# vel  -4 -4
# vel  6 6
# vel  3 2
# vel  3 1
# vel  6 -5
# vel  1 0
# vel  2 0
# vel  3 -2
# vel  3 -3
# vel  4 -3
# vel  -1 -5
# vel  2 2
# vel  5 3
# vel  1 1
# vel  2 0
# vel  1 0
# vel  1 1
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  2 -5
# vel  2 4
# vel  0 2
# vel  1 1
# vel  1 0
# vel  0 0
# vel  0 0
# vel  1 0
# vel  0 0
# vel  1 -1
# vel  1 -1
# vel  1 -1
# vel  -1 -6
# vel  -5 4
# vel  0 4
# vel  1 3
# vel  1 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  1 -3
# vel  4 -4
# vel  2 5
# vel  -1 3
# vel  0 1
# vel  -4 5
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  -5 4
# vel  -6 -4
# vel  0 -2
# vel  0 -4
# vel  1 -5
# vel  -6 -7
# vel  -2 3
# vel  -1 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  0 -1
# vel  0 -4
# vel  4 6
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  -1 0
# vel  0 0
# vel  0 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -3
# vel  -2 -6
# vel  -1 5
# vel  -1 2
# vel  0 1
# vel  -1 1
# vel  0 1
# vel  -1 1
# vel  -3 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -2
# vel  -2 -4
# vel  -4 3
# vel  -1 5
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -1 -1
# vel  -1 -1
# vel  -2 -2
# vel  -2 -5
# vel  -4 4
# vel  -1 2
# vel  -2 1
# vel  -1 0
# vel  -1 0
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -2 -2
# vel  -6 -7
# vel  -3 -4
# vel  -5 3
# vel  -3 2
# vel  -3 1
# vel  -4 5
# vel  -2 0
# vel  -1 -1
# vel  -7 -7
# vel  -5 1
# vel  -4 -3
# vel  5 -2
# vel  -6 3
# vel  -6 4
# vel  -6 -3
# vel  -6 3
# vel  -6 -4
# ------------ Step 2 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00580.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00570.png
# vel  3 3
# vel  5 1
# vel  7 -5
# vel  6 -1
# vel  3 4
# vel  5 -4
# vel  4 3
# vel  2 1
# vel  3 0
# vel  2 0
# vel  1 0
# vel  1 0
# vel  2 -2
# vel  5 -1
# vel  5 -2
# vel  2 3
# vel  2 2
# vel  1 1
# vel  -7 3
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -3
# vel  2 -5
# vel  4 5
# vel  0 2
# vel  1 1
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -3
# vel  1 4
# vel  1 3
# vel  1 1
# vel  1 1
# vel  0 0
# vel  1 0
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  0 -1
# vel  1 -2
# vel  1 -3
# vel  2 -4
# vel  2 5
# vel  0 3
# vel  0 1
# vel  1 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -2
# vel  1 -3
# vel  0 -4
# vel  1 -6
# vel  -2 4
# vel  0 2
# vel  0 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  0 -2
# vel  0 -4
# vel  -5 6
# vel  0 2
# vel  0 1
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  -1 -1
# vel  -1 -4
# vel  -5 -7
# vel  -1 4
# vel  0 6
# vel  0 1
# vel  -1 1
# vel  0 1
# vel  0 1
# vel  -1 0
# vel  0 0
# vel  -2 0
# vel  -1 -1
# vel  -1 -2
# vel  -1 -2
# vel  -2 -6
# vel  7 -7
# vel  -6 5
# vel  -1 2
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -1 -1
# vel  -2 -2
# vel  -3 -3
# vel  -3 -5
# vel  -6 5
# vel  -6 -4
# vel  -2 1
# vel  -2 0
# vel  -1 0
# vel  -2 -1
# vel  -1 0
# vel  -2 -1
# vel  -2 -2
# vel  -4 -7
# vel  -3 -4
# vel  -5 3
# vel  -3 2
# vel  -3 0
# vel  -2 0
# vel  -3 0
# vel  -2 -1
# vel  -2 -1
# vel  -5 -4
# vel  -4 -3
# vel  -7 5
# vel  -7 3
# vel  -7 -5
# vel  -6 4
# vel  -5 -2
# ------------ Step 3 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00570.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00560.png
# vel  1 1
# vel  5 1
# vel  4 0
# vel  4 -1
# vel  6 1
# vel  5 -3
# vel  4 3
# vel  5 4
# vel  3 0
# vel  2 0
# vel  4 1
# vel  2 -1
# vel  2 -2
# vel  5 -1
# vel  5 -3
# vel  3 3
# vel  2 2
# vel  2 0
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  2 -2
# vel  3 -3
# vel  3 -4
# vel  3 5
# vel  3 2
# vel  1 2
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -2
# vel  -1 -7
# vel  1 4
# vel  1 3
# vel  1 1
# vel  1 1
# vel  0 0
# vel  0 0
# vel  1 0
# vel  0 -1
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  1 -3
# vel  3 -4
# vel  -3 -1
# vel  0 3
# vel  -4 -4
# vel  1 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -2
# vel  0 -4
# vel  0 -4
# vel  -6 7
# vel  -2 4
# vel  1 2
# vel  0 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -2
# vel  0 -2
# vel  0 -4
# vel  -1 3
# vel  -1 2
# vel  0 2
# vel  0 1
# vel  0 1
# vel  0 1
# vel  -1 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  -1 -1
# vel  -1 -3
# vel  0 -6
# vel  -3 3
# vel  -2 2
# vel  0 1
# vel  -1 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -3
# vel  -1 -5
# vel  4 -5
# vel  -2 3
# vel  -1 2
# vel  -2 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -1 -1
# vel  -2 -2
# vel  -2 -3
# vel  -2 -5
# vel  -6 5
# vel  -2 3
# vel  -2 1
# vel  -2 1
# vel  -1 0
# vel  -2 0
# vel  -1 0
# vel  -2 -1
# vel  -2 -2
# vel  -2 -2
# vel  -5 -6
# vel  -5 3
# vel  -4 4
# vel  -4 2
# vel  -2 0
# vel  -3 0
# vel  0 -6
# vel  -3 0
# vel  -3 -2
# vel  -4 -3
# vel  -4 0
# vel  -6 2
# vel  -7 -5
# vel  -4 -1
# vel  -6 -5
# ------------ Step 4 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00560.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00550.png
# vel  -7 -7
# vel  6 3
# vel  4 0
# vel  3 -1
# vel  4 -1
# vel  4 -3
# vel  3 2
# vel  2 1
# vel  3 1
# vel  2 0
# vel  4 1
# vel  2 -1
# vel  2 -2
# vel  3 -3
# vel  5 -3
# vel  3 3
# vel  1 2
# vel  1 0
# vel  2 1
# vel  1 1
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  1 -1
# vel  3 -3
# vel  3 -4
# vel  3 5
# vel  4 5
# vel  1 1
# vel  1 1
# vel  0 0
# vel  0 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  2 -4
# vel  1 4
# vel  0 3
# vel  1 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  1 -1
# vel  1 -3
# vel  4 -7
# vel  0 -7
# vel  -3 6
# vel  0 2
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -3
# vel  0 -4
# vel  0 6
# vel  -1 3
# vel  1 2
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  0 -2
# vel  -1 -3
# vel  -1 4
# vel  0 2
# vel  0 1
# vel  0 0
# vel  0 1
# vel  -1 1
# vel  -1 1
# vel  -2 -1
# vel  0 -1
# vel  -1 -1
# vel  -1 -1
# vel  0 -3
# vel  1 -6
# vel  -2 3
# vel  -1 2
# vel  0 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  0 -1
# vel  1 2
# vel  -3 1
# vel  -1 0
# vel  -1 -1
# vel  0 -2
# vel  3 -6
# vel  0 5
# vel  -2 2
# vel  -2 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -3
# vel  -2 -5
# vel  -4 3
# vel  -5 4
# vel  -2 1
# vel  -2 0
# vel  -1 0
# vel  0 -3
# vel  -1 0
# vel  -1 -1
# vel  -2 -2
# vel  -2 -2
# vel  -4 -6
# vel  -5 2
# vel  -3 2
# vel  -3 0
# vel  -2 0
# vel  -2 -4
# vel  -7 -7
# vel  -2 0
# vel  -7 -2
# vel  -4 -3
# vel  -7 4
# vel  -5 0
# vel  -6 -4
# vel  -4 0
# vel  -4 -2
# ------------ Step 5 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00550.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00540.png
# vel  -4 -5
# vel  4 2
# vel  3 0
# vel  4 -1
# vel  6 0
# vel  6 -4
# vel  4 4
# vel  3 2
# vel  3 1
# vel  7 5
# vel  3 -2
# vel  2 4
# vel  2 -2
# vel  3 -3
# vel  5 -3
# vel  3 4
# vel  1 2
# vel  3 3
# vel  4 -1
# vel  1 1
# vel  1 0
# vel  2 -1
# vel  1 -1
# vel  1 -1
# vel  2 -3
# vel  2 -4
# vel  4 6
# vel  2 4
# vel  1 2
# vel  1 1
# vel  0 0
# vel  0 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  1 -6
# vel  3 5
# vel  1 3
# vel  2 2
# vel  1 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  0 -1
# vel  5 -3
# vel  1 -2
# vel  1 -3
# vel  3 -6
# vel  0 3
# vel  0 1
# vel  -5 5
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -2
# vel  0 -3
# vel  0 -4
# vel  -2 4
# vel  0 2
# vel  0 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 0
# vel  0 -1
# vel  0 -2
# vel  0 -3
# vel  -5 -6
# vel  -1 3
# vel  0 2
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  -1 1
# vel  0 0
# vel  0 -1
# vel  0 0
# vel  -1 -1
# vel  0 -3
# vel  -1 -4
# vel  -3 4
# vel  -2 2
# vel  1 6
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  0 -1
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  -1 -1
# vel  -1 -2
# vel  2 -6
# vel  0 5
# vel  -2 2
# vel  -2 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  -5 3
# vel  -1 -2
# vel  -2 -3
# vel  -2 -5
# vel  -6 4
# vel  -5 4
# vel  2 5
# vel  -2 0
# vel  6 5
# vel  -2 0
# vel  -1 -1
# vel  3 7
# vel  5 -4
# vel  -2 -2
# vel  -3 -4
# vel  -6 3
# vel  -3 3
# vel  -5 -6
# vel  -2 0
# vel  -2 -4
# vel  -3 -2
# vel  2 4
# vel  -4 -2
# vel  -5 -3
# vel  -7 5
# vel  -6 -1
# vel  -6 -2
# vel  -5 -1
# vel  -6 -5
# ------------ Step 6 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00540.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00530.png
# vel  5 1
# vel  4 0
# vel  4 -1
# vel  6 -1
# vel  6 -4
# vel  6 4
# vel  4 4
# vel  3 1
# vel  1 0
# vel  2 -1
# vel  3 -2
# vel  3 -3
# vel  2 -6
# vel  5 -3
# vel  6 6
# vel  2 2
# vel  2 1
# vel  2 1
# vel  1 1
# vel  1 0
# vel  2 -1
# vel  1 -1
# vel  1 -1
# vel  3 -3
# vel  2 -4
# vel  1 4
# vel  1 3
# vel  1 2
# vel  1 0
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  5 -7
# vel  1 -1
# vel  2 -3
# vel  2 -4
# vel  1 4
# vel  1 3
# vel  1 2
# vel  1 1
# vel  0 0
# vel  0 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  0 -1
# vel  1 -3
# vel  1 -4
# vel  1 -4
# vel  4 5
# vel  1 2
# vel  1 1
# vel  0 1
# vel  0 1
# vel  1 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -2
# vel  0 -4
# vel  0 -4
# vel  -2 3
# vel  0 3
# vel  0 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  -4 -2
# vel  0 -2
# vel  0 -2
# vel  1 -6
# vel  -3 4
# vel  0 2
# vel  0 2
# vel  0 1
# vel  0 1
# vel  -1 1
# vel  -1 0
# vel  0 0
# vel  3 -4
# vel  -1 -1
# vel  -1 -1
# vel  0 -3
# vel  -1 -4
# vel  -2 5
# vel  -2 1
# vel  1 3
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -2
# vel  -2 -4
# vel  2 6
# vel  -2 2
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  -7 6
# vel  -2 -2
# vel  -4 -4
# vel  -2 -4
# vel  -6 6
# vel  -4 2
# vel  -6 5
# vel  -2 1
# vel  -2 0
# vel  -2 0
# vel  -2 -1
# vel  -2 -2
# vel  -2 -2
# vel  -3 -2
# vel  -7 -7
# vel  -4 2
# vel  -4 5
# vel  -5 1
# vel  -2 0
# vel  -2 -5
# vel  -3 -1
# vel  -3 -1
# vel  -2 -2
# vel  -4 -3
# vel  -5 6
# vel  -6 -1
# vel  -6 -2
# vel  -5 -1
# vel  -4 -1
# ------------ Step 7 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00530.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00520.png
# vel  5 1
# vel  7 -7
# vel  4 -1
# vel  4 -1
# vel  5 -3
# vel  4 6
# vel  3 6
# vel  3 1
# vel  3 3
# vel  2 -5
# vel  6 4
# vel  6 3
# vel  5 -6
# vel  4 -3
# vel  5 5
# vel  6 0
# vel  2 1
# vel  2 1
# vel  1 1
# vel  2 0
# vel  5 2
# vel  1 -1
# vel  2 -2
# vel  2 -3
# vel  3 -4
# vel  1 4
# vel  5 2
# vel  1 3
# vel  1 1
# vel  1 1
# vel  1 0
# vel  2 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -5
# vel  2 -5
# vel  1 4
# vel  3 4
# vel  1 2
# vel  1 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  1 -1
# vel  0 -2
# vel  1 -2
# vel  1 -4
# vel  1 -6
# vel  2 5
# vel  1 2
# vel  0 1
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 0
# vel  1 -1
# vel  2 -2
# vel  0 -3
# vel  0 -4
# vel  -1 3
# vel  0 3
# vel  0 2
# vel  -1 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  0 -1
# vel  0 -1
# vel  0 -1
# vel  7 -6
# vel  0 -5
# vel  0 4
# vel  0 3
# vel  0 2
# vel  0 1
# vel  -1 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  -1 -1
# vel  -1 -1
# vel  0 -3
# vel  4 -6
# vel  -1 4
# vel  -2 2
# vel  -1 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  1 0
# vel  0 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -3
# vel  0 -6
# vel  -6 4
# vel  -6 6
# vel  -2 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  -1 -2
# vel  -2 -2
# vel  -2 -3
# vel  -1 -6
# vel  -6 4
# vel  -2 3
# vel  -3 0
# vel  -2 0
# vel  -2 0
# vel  -2 0
# vel  -2 -1
# vel  -2 -2
# vel  -2 -2
# vel  -2 -3
# vel  -6 -7
# vel  -3 3
# vel  -6 4
# vel  -6 2
# vel  -4 3
# vel  -6 6
# vel  -7 -7
# vel  -7 6
# vel  -2 -2
# vel  -5 -4
# vel  -4 0
# vel  -6 1
# vel  -6 1
# vel  -5 -1
# vel  -7 -2
# ------------ Step 8 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00520.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00510.png
# vel  5 3
# vel  5 0
# vel  5 2
# vel  4 -1
# vel  5 -2
# vel  4 3
# vel  4 3
# vel  3 1
# vel  4 3
# vel  6 -7
# vel  2 -2
# vel  5 -1
# vel  3 -3
# vel  3 -3
# vel  5 3
# vel  3 2
# vel  2 1
# vel  2 1
# vel  2 1
# vel  2 0
# vel  5 -6
# vel  1 -1
# vel  2 -3
# vel  2 -4
# vel  3 -3
# vel  1 5
# vel  1 3
# vel  1 2
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  6 -7
# vel  1 -2
# vel  2 -4
# vel  4 -6
# vel  0 4
# vel  0 3
# vel  2 3
# vel  1 2
# vel  0 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  1 -2
# vel  2 -4
# vel  1 -5
# vel  2 6
# vel  0 2
# vel  0 1
# vel  1 2
# vel  0 1
# vel  0 0
# vel  0 -1
# vel  1 -1
# vel  1 0
# vel  1 -1
# vel  1 -2
# vel  0 -3
# vel  0 -4
# vel  2 5
# vel  -7 -7
# vel  -1 2
# vel  -1 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  0 -1
# vel  0 -1
# vel  1 -3
# vel  0 -4
# vel  -3 4
# vel  0 3
# vel  0 2
# vel  0 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  -1 -2
# vel  0 -3
# vel  3 -6
# vel  -3 3
# vel  -2 3
# vel  -1 2
# vel  -3 3
# vel  -1 1
# vel  -1 1
# vel  -1 1
# vel  -1 -1
# vel  -2 -1
# vel  -1 -1
# vel  -2 -2
# vel  -1 -3
# vel  -2 -5
# vel  -6 3
# vel  -7 5
# vel  -2 2
# vel  -1 1
# vel  -2 0
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -1 -1
# vel  -2 -3
# vel  -2 -3
# vel  -2 -7
# vel  -7 3
# vel  -4 5
# vel  -5 3
# vel  -2 1
# vel  -2 0
# vel  -2 0
# vel  -3 -1
# vel  -2 -2
# vel  3 3
# vel  -2 -3
# vel  -2 -3
# vel  -3 3
# vel  -7 6
# vel  -7 1
# vel  -4 -5
# vel  -7 -1
# vel  -7 -7
# vel  -7 1
# vel  -2 4
# vel  -6 -5
# vel  -4 0
# vel  -5 -1
# vel  -5 -1
# vel  -5 0
# vel  -5 0
# ------------ Step 9 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00510.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00500.png
# vel  5 3
# vel  6 0
# vel  5 -1
# vel  6 -1
# vel  6 -1
# vel  4 4
# vel  1 3
# vel  3 0
# vel  4 1
# vel  5 -7
# vel  0 0
# vel  3 -3
# vel  5 -4
# vel  4 -2
# vel  4 2
# vel  2 3
# vel  2 1
# vel  2 0
# vel  1 1
# vel  2 -1
# vel  2 -1
# vel  1 -1
# vel  6 -1
# vel  3 -3
# vel  2 -3
# vel  1 4
# vel  5 0
# vel  1 2
# vel  2 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  2 -1
# vel  1 -2
# vel  2 -3
# vel  4 -5
# vel  1 5
# vel  5 6
# vel  1 2
# vel  1 2
# vel  0 0
# vel  1 0
# vel  1 0
# vel  2 -1
# vel  1 0
# vel  1 -2
# vel  1 -2
# vel  4 -4
# vel  2 -4
# vel  0 6
# vel  2 4
# vel  0 1
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  1 0
# vel  4 -1
# vel  1 -2
# vel  1 -3
# vel  1 -4
# vel  -1 3
# vel  0 3
# vel  0 2
# vel  0 1
# vel  0 0
# vel  -1 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  0 -1
# vel  1 -6
# vel  0 -3
# vel  -4 5
# vel  -1 3
# vel  0 2
# vel  0 1
# vel  0 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  0 -1
# vel  -1 -1
# vel  -2 -2
# vel  0 -6
# vel  -4 3
# vel  -3 3
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -2 -2
# vel  -2 -4
# vel  0 -6
# vel  -3 2
# vel  -3 5
# vel  -2 1
# vel  -1 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -1 -1
# vel  -2 -2
# vel  -2 -4
# vel  -2 -6
# vel  -3 2
# vel  -6 5
# vel  -6 4
# vel  -2 1
# vel  -3 0
# vel  -2 0
# vel  -7 -6
# vel  -2 -2
# vel  -5 1
# vel  -2 -2
# vel  -2 -3
# vel  -4 3
# vel  -6 4
# vel  -6 1
# vel  -5 0
# vel  -4 0
# vel  -3 0
# vel  -5 -2
# vel  -5 0
# vel  -5 -5
# vel  -6 0
# vel  -5 0
# vel  -5 0
# vel  -5 -1
# vel  -6 -1
# ------------ Step 10 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00500.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00490.png
# vel  6 3
# vel  6 2
# vel  5 -1
# vel  6 4
# vel  5 -1
# vel  3 1
# vel  2 1
# vel  3 0
# vel  3 0
# vel  6 -6
# vel  4 -1
# vel  3 -2
# vel  3 -3
# vel  4 -3
# vel  5 2
# vel  2 3
# vel  3 1
# vel  5 3
# vel  2 1
# vel  2 0
# vel  2 -1
# vel  2 -1
# vel  4 -2
# vel  4 -3
# vel  -6 6
# vel  2 4
# vel  2 4
# vel  1 2
# vel  2 4
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  3 -6
# vel  1 -2
# vel  3 -4
# vel  4 -5
# vel  2 5
# vel  1 2
# vel  1 2
# vel  1 2
# vel  0 0
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  0 -2
# vel  5 6
# vel  3 -5
# vel  2 -5
# vel  0 3
# vel  1 3
# vel  1 1
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 0
# vel  -3 1
# vel  1 1
# vel  1 -3
# vel  2 -5
# vel  -1 6
# vel  1 3
# vel  0 2
# vel  0 1
# vel  0 0
# vel  0 -1
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  1 -1
# vel  0 -2
# vel  -1 -2
# vel  -1 -4
# vel  -5 6
# vel  3 5
# vel  0 1
# vel  0 1
# vel  0 1
# vel  0 0
# vel  -1 0
# vel  -1 0
# vel  -1 -1
# vel  0 -1
# vel  -2 -2
# vel  -2 -2
# vel  -2 -3
# vel  -3 3
# vel  -3 3
# vel  -1 2
# vel  -1 1
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -2 -2
# vel  -1 -3
# vel  -2 -5
# vel  -2 2
# vel  -6 4
# vel  -2 2
# vel  -2 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -2 -1
# vel  -1 -1
# vel  -6 -6
# vel  -4 -7
# vel  -4 -7
# vel  -3 2
# vel  -3 3
# vel  -3 1
# vel  -3 1
# vel  -1 4
# vel  -2 0
# vel  -2 0
# vel  -2 -2
# vel  -6 -3
# vel  -2 -2
# vel  -5 -7
# vel  -4 3
# vel  -6 1
# vel  -7 0
# vel  -6 0
# vel  -4 0
# vel  -4 0
# vel  -6 -3
# vel  -6 -2
# vel  -4 -4
# vel  -7 1
# vel  -6 1
# vel  -6 1
# vel  -5 -1
# vel  -5 -1
# ------------ Step 11 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00490.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00480.png
# vel  6 2
# vel  6 -1
# vel  3 -1
# vel  5 0
# vel  5 -1
# vel  3 2
# vel  3 2
# vel  3 0
# vel  3 0
# vel  3 0
# vel  5 0
# vel  3 -3
# vel  3 -4
# vel  -1 2
# vel  4 3
# vel  1 3
# vel  2 3
# vel  3 0
# vel  1 1
# vel  2 0
# vel  2 -1
# vel  2 -2
# vel  2 -2
# vel  5 -3
# vel  -1 6
# vel  2 4
# vel  5 2
# vel  1 2
# vel  1 2
# vel  1 1
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -2
# vel  2 -3
# vel  3 -4
# vel  3 4
# vel  1 2
# vel  1 2
# vel  1 1
# vel  0 0
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -2
# vel  4 1
# vel  4 -5
# vel  1 -5
# vel  2 5
# vel  2 6
# vel  1 2
# vel  0 1
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 0
# vel  0 -2
# vel  1 3
# vel  1 -5
# vel  1 -5
# vel  0 4
# vel  0 3
# vel  -1 1
# vel  -1 1
# vel  0 0
# vel  0 -1
# vel  -1 0
# vel  0 0
# vel  1 -1
# vel  1 -1
# vel  7 6
# vel  3 -7
# vel  -6 -7
# vel  -1 3
# vel  -1 3
# vel  0 2
# vel  -1 6
# vel  0 1
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  0 0
# vel  1 -2
# vel  -7 6
# vel  1 -6
# vel  -1 -6
# vel  -3 4
# vel  -5 4
# vel  -2 1
# vel  -5 6
# vel  3 -3
# vel  -6 7
# vel  0 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  3 -3
# vel  -2 -5
# vel  -2 -6
# vel  -3 2
# vel  -6 -5
# vel  -2 2
# vel  -2 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  -2 -2
# vel  -2 -2
# vel  -2 -1
# vel  -1 -5
# vel  -3 -6
# vel  -4 3
# vel  -3 3
# vel  -7 1
# vel  -7 0
# vel  -3 0
# vel  -1 0
# vel  -7 7
# vel  -6 2
# vel  -4 -3
# vel  -3 -3
# vel  -2 -3
# vel  -3 1
# vel  -6 1
# vel  -7 0
# vel  -4 0
# vel  -4 0
# vel  -4 0
# vel  -7 -4
# vel  -5 -2
# vel  -4 -3
# vel  -5 -1
# vel  -4 0
# vel  -4 0
# vel  -6 -1
# vel  -6 -1
# ------------ Step 12 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00480.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00470.png
# vel  5 1
# vel  6 0
# vel  4 -2
# vel  5 -2
# vel  4 -2
# vel  3 2
# vel  4 4
# vel  3 0
# vel  3 0
# vel  3 0
# vel  4 -2
# vel  4 -2
# vel  5 -6
# vel  -7 6
# vel  4 2
# vel  1 7
# vel  2 2
# vel  3 1
# vel  2 1
# vel  2 0
# vel  3 -1
# vel  3 -2
# vel  2 -2
# vel  6 -3
# vel  2 5
# vel  5 4
# vel  1 3
# vel  2 1
# vel  1 1
# vel  1 1
# vel  2 0
# vel  1 -1
# vel  2 -1
# vel  1 -2
# vel  2 -4
# vel  5 -3
# vel  1 5
# vel  -7 2
# vel  1 3
# vel  1 2
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -3
# vel  4 -2
# vel  1 -3
# vel  3 -7
# vel  -1 4
# vel  0 5
# vel  1 2
# vel  1 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  1 0
# vel  0 -2
# vel  1 -3
# vel  -2 -6
# vel  1 -5
# vel  -1 4
# vel  -1 3
# vel  -4 6
# vel  2 3
# vel  0 1
# vel  0 0
# vel  0 0
# vel  5 3
# vel  1 -1
# vel  1 -1
# vel  4 0
# vel  0 -3
# vel  -2 -7
# vel  4 5
# vel  -1 4
# vel  -1 3
# vel  0 1
# vel  -1 2
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -3
# vel  -1 -4
# vel  -1 -4
# vel  -4 4
# vel  -3 3
# vel  -2 1
# vel  -1 1
# vel  -1 2
# vel  -1 1
# vel  -1 1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -2 -2
# vel  -2 -4
# vel  -2 -5
# vel  -5 5
# vel  -2 1
# vel  -2 2
# vel  -2 1
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  -2 -2
# vel  -2 -2
# vel  -2 -2
# vel  -1 -5
# vel  -2 -7
# vel  -5 5
# vel  -4 2
# vel  -1 4
# vel  -3 -4
# vel  -4 1
# vel  -2 0
# vel  -2 0
# vel  -2 -2
# vel  -3 -3
# vel  -3 -3
# vel  -4 -2
# vel  -1 0
# vel  -7 -3
# vel  -5 0
# vel  -4 -1
# vel  -5 0
# vel  -5 0
# vel  -3 -2
# vel  -3 -3
# vel  -5 0
# vel  -7 -3
# vel  -4 -1
# vel  -4 -1
# vel  -6 -1
# vel  -6 -1
# ------------ Step 13 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00470.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00460.png
# vel  6 0
# vel  6 0
# vel  5 -2
# vel  4 -2
# vel  4 -2
# vel  4 2
# vel  3 4
# vel  3 4
# vel  2 0
# vel  2 0
# vel  4 -2
# vel  4 -2
# vel  4 -3
# vel  4 1
# vel  2 3
# vel  3 1
# vel  3 1
# vel  2 1
# vel  -7 -7
# vel  7 7
# vel  4 -2
# vel  4 -3
# vel  4 -4
# vel  2 4
# vel  3 5
# vel  2 3
# vel  2 4
# vel  5 3
# vel  1 1
# vel  2 0
# vel  2 -1
# vel  1 -2
# vel  5 -6
# vel  1 -3
# vel  1 -3
# vel  1 6
# vel  0 5
# vel  1 2
# vel  3 -5
# vel  2 -7
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -3
# vel  1 -4
# vel  1 -4
# vel  2 -5
# vel  0 4
# vel  1 4
# vel  0 2
# vel  1 2
# vel  0 1
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  4 3
# vel  1 -3
# vel  1 -4
# vel  1 -5
# vel  0 4
# vel  -1 3
# vel  1 5
# vel  -1 2
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 -1
# vel  1 -3
# vel  0 -4
# vel  -3 -6
# vel  1 5
# vel  -2 3
# vel  0 2
# vel  0 1
# vel  -1 1
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  -1 -1
# vel  0 -1
# vel  0 -2
# vel  -5 -4
# vel  -5 -5
# vel  6 -7
# vel  0 3
# vel  -1 2
# vel  -1 1
# vel  -1 2
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  4 -7
# vel  -1 -6
# vel  -2 -7
# vel  -6 6
# vel  -2 2
# vel  -2 2
# vel  -7 -2
# vel  -2 0
# vel  -2 0
# vel  -1 0
# vel  -2 -1
# vel  -2 -2
# vel  -2 -2
# vel  -2 -3
# vel  -1 -6
# vel  -6 6
# vel  -5 2
# vel  -3 1
# vel  -3 0
# vel  -3 0
# vel  -3 0
# vel  -4 -2
# vel  0 2
# vel  -3 -3
# vel  -3 -3
# vel  -3 -3
# vel  7 -7
# vel  -4 0
# vel  -4 0
# vel  -4 0
# vel  -3 0
# vel  -3 0
# vel  -3 5
# vel  -3 -3
# vel  -4 -3
# vel  -6 -3
# vel  -4 0
# vel  -4 0
# vel  -6 -1
# vel  -7 0
# ------------ Step 14 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00460.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00450.png
# vel  4 0
# vel  4 0
# vel  5 -2
# vel  6 -1
# vel  5 -2
# vel  5 5
# vel  4 2
# vel  3 1
# vel  4 3
# vel  4 3
# vel  4 -2
# vel  4 -3
# vel  3 -3
# vel  3 3
# vel  3 3
# vel  2 2
# vel  3 1
# vel  2 1
# vel  4 -6
# vel  2 -1
# vel  3 -3
# vel  3 -3
# vel  4 -5
# vel  2 4
# vel  4 5
# vel  2 3
# vel  2 1
# vel  1 0
# vel  1 1
# vel  2 0
# vel  1 -1
# vel  2 -1
# vel  2 -3
# vel  2 -3
# vel  2 -2
# vel  1 4
# vel  5 5
# vel  1 2
# vel  1 2
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -2
# vel  2 -5
# vel  2 -5
# vel  4 -6
# vel  1 4
# vel  2 6
# vel  1 2
# vel  1 1
# vel  0 1
# vel  1 0
# vel  0 0
# vel  1 0
# vel  1 -1
# vel  0 -1
# vel  1 -4
# vel  1 -4
# vel  2 -5
# vel  0 4
# vel  -1 4
# vel  1 3
# vel  0 1
# vel  0 0
# vel  0 0
# vel  -1 0
# vel  0 0
# vel  0 -1
# vel  0 -1
# vel  1 -3
# vel  1 -3
# vel  5 -6
# vel  -2 4
# vel  -3 4
# vel  -1 2
# vel  0 1
# vel  0 1
# vel  -1 0
# vel  -1 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 -3
# vel  -5 -3
# vel  -7 -4
# vel  2 -5
# vel  -4 4
# vel  -2 2
# vel  -1 1
# vel  -1 2
# vel  -1 1
# vel  -1 0
# vel  -2 -1
# vel  0 0
# vel  -1 -1
# vel  -1 -4
# vel  1 -6
# vel  -2 -5
# vel  -3 5
# vel  -2 2
# vel  -2 2
# vel  -1 2
# vel  -2 0
# vel  -7 -5
# vel  -2 1
# vel  -2 -1
# vel  -4 -1
# vel  -3 -3
# vel  -2 -6
# vel  -1 -6
# vel  -4 5
# vel  -4 2
# vel  -3 1
# vel  -3 1
# vel  -3 0
# vel  -4 -1
# vel  -7 6
# vel  -5 0
# vel  -3 -3
# vel  -3 -3
# vel  -7 -3
# vel  4 -5
# vel  -4 0
# vel  -4 0
# vel  -4 0
# vel  -5 -2
# vel  -5 -2
# vel  -5 -1
# vel  -3 -3
# vel  -4 -3
# vel  -4 1
# vel  -4 0
# vel  -4 0
# vel  -7 -1
# vel  -6 -4
# ------------ Step 15 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00450.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00440.png
# vel  5 1
# vel  5 1
# vel  6 -2
# vel  6 -1
# vel  6 -1
# vel  5 3
# vel  4 4
# vel  5 3
# vel  3 -3
# vel  4 -2
# vel  6 0
# vel  4 -3
# vel  4 -3
# vel  3 4
# vel  3 3
# vel  4 2
# vel  3 1
# vel  -1 -5
# vel  4 -7
# vel  3 -1
# vel  4 -3
# vel  4 -4
# vel  4 -3
# vel  3 4
# vel  5 5
# vel  2 3
# vel  2 0
# vel  2 1
# vel  1 1
# vel  3 0
# vel  2 -1
# vel  2 -1
# vel  6 -5
# vel  2 -4
# vel  2 -3
# vel  3 6
# vel  3 4
# vel  2 2
# vel  1 2
# vel  2 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -3
# vel  1 -4
# vel  1 -4
# vel  1 -4
# vel  0 3
# vel  1 3
# vel  1 2
# vel  0 2
# vel  0 1
# vel  1 0
# vel  0 0
# vel  1 -1
# vel  1 -1
# vel  1 -2
# vel  1 -4
# vel  1 -4
# vel  1 -6
# vel  0 4
# vel  -1 4
# vel  0 2
# vel  -1 2
# vel  0 0
# vel  0 0
# vel  0 0
# vel  0 0
# vel  1 -1
# vel  1 -1
# vel  0 -3
# vel  0 -3
# vel  1 -3
# vel  -2 4
# vel  -3 4
# vel  -2 2
# vel  -1 2
# vel  0 2
# vel  -1 1
# vel  -1 0
# vel  0 0
# vel  -6 -7
# vel  1 0
# vel  0 -3
# vel  -2 -4
# vel  -2 -4
# vel  -4 4
# vel  -4 6
# vel  -1 2
# vel  -1 2
# vel  -1 1
# vel  -1 -1
# vel  -2 -1
# vel  -1 -1
# vel  -1 -1
# vel  -2 -2
# vel  -2 -6
# vel  -2 -6
# vel  -3 5
# vel  -2 2
# vel  -2 2
# vel  -1 2
# vel  -2 0
# vel  -2 0
# vel  -3 0
# vel  -2 -1
# vel  -3 -3
# vel  -5 -6
# vel  -5 -6
# vel  -4 -7
# vel  -4 5
# vel  -4 2
# vel  -5 2
# vel  -6 1
# vel  -4 -1
# vel  -3 0
# vel  -3 0
# vel  -6 1
# vel  -5 -5
# vel  -4 -4
# vel  -6 -5
# vel  -6 3
# vel  -5 2
# vel  -5 -2
# vel  -4 -1
# vel  -4 0
# vel  -6 1
# vel  -5 -4
# vel  -6 -3
# vel  -5 -1
# vel  -6 -4
# vel  -6 -4
# vel  -4 -3
# vel  -4 -2
# ------------ Step 16 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00440.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00430.png
# vel  6 3
# vel  6 3
# vel  5 0
# vel  4 -3
# vel  5 -5
# vel  5 4
# vel  5 6
# vel  5 4
# vel  5 1
# vel  5 1
# vel  5 -4
# vel  4 -3
# vel  4 -6
# vel  4 3
# vel  3 3
# vel  4 2
# vel  3 1
# vel  5 1
# vel  5 -1
# vel  3 -2
# vel  4 -6
# vel  3 -4
# vel  3 -4
# vel  2 4
# vel  3 5
# vel  2 3
# vel  2 1
# vel  2 1
# vel  0 1
# vel  2 -1
# vel  5 -4
# vel  1 -1
# vel  7 -5
# vel  2 -4
# vel  2 -4
# vel  0 6
# vel  1 4
# vel  1 3
# vel  1 3
# vel  1 1
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  2 -3
# vel  1 -4
# vel  1 -4
# vel  1 -5
# vel  0 5
# vel  1 6
# vel  1 3
# vel  1 2
# vel  0 1
# vel  0 0
# vel  1 0
# vel  1 -1
# vel  1 0
# vel  1 -2
# vel  0 -3
# vel  0 -4
# vel  1 -5
# vel  0 5
# vel  -2 5
# vel  0 2
# vel  -1 2
# vel  0 1
# vel  0 0
# vel  -1 0
# vel  0 0
# vel  0 0
# vel  -2 -2
# vel  -1 -6
# vel  -1 -6
# vel  1 -4
# vel  -7 6
# vel  -3 4
# vel  -2 2
# vel  2 6
# vel  0 1
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  0 0
# vel  1 0
# vel  -1 -6
# vel  -2 -4
# vel  -2 -4
# vel  -4 4
# vel  -5 6
# vel  -1 2
# vel  -1 2
# vel  -2 1
# vel  -3 -1
# vel  -1 -1
# vel  -1 -1
# vel  -1 -1
# vel  -2 -2
# vel  -1 -7
# vel  1 -7
# vel  -5 6
# vel  -6 4
# vel  -2 2
# vel  -1 2
# vel  0 -7
# vel  -2 0
# vel  -2 0
# vel  -5 2
# vel  -6 -2
# vel  -2 -2
# vel  -4 -7
# vel  -4 -7
# vel  -5 5
# vel  -6 3
# vel  -3 2
# vel  -3 4
# vel  -5 0
# vel  -4 0
# vel  -3 -1
# vel  -3 -3
# vel  -3 -3
# vel  -4 -3
# vel  -6 -4
# vel  -3 2
# vel  -3 2
# vel  -6 0
# vel  -5 -1
# vel  -4 0
# vel  -3 -3
# vel  -3 -3
# vel  -4 -3
# vel  -5 0
# vel  -6 1
# vel  -6 1
# vel  -6 -2
# vel  -5 -1
# ------------ Step 17 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00430.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00420.png
# vel  4 3
# vel  4 3
# vel  6 -1
# vel  4 -3
# vel  4 -2
# vel  5 4
# vel  5 6
# vel  4 5
# vel  5 0
# vel  5 0
# vel  4 -2
# vel  4 -2
# vel  2 -3
# vel  4 4
# vel  3 3
# vel  5 2
# vel  3 3
# vel  5 0
# vel  5 -2
# vel  3 -2
# vel  3 -2
# vel  5 -4
# vel  3 -5
# vel  2 4
# vel  2 4
# vel  3 3
# vel  1 2
# vel  1 2
# vel  1 1
# vel  3 -1
# vel  3 -1
# vel  2 -1
# vel  1 -2
# vel  3 -4
# vel  2 -4
# vel  2 4
# vel  1 5
# vel  1 3
# vel  1 1
# vel  7 -7
# vel  2 0
# vel  6 -2
# vel  1 -1
# vel  1 -1
# vel  6 -6
# vel  0 -4
# vel  0 -4
# vel  3 -6
# vel  1 4
# vel  1 3
# vel  1 2
# vel  0 2
# vel  0 1
# vel  0 0
# vel  1 0
# vel  1 0
# vel  1 -1
# vel  0 -3
# vel  0 -3
# vel  0 -4
# vel  2 -5
# vel  0 4
# vel  0 4
# vel  -1 2
# vel  -1 2
# vel  0 1
# vel  0 0
# vel  -1 0
# vel  0 -1
# vel  7 -7
# vel  -4 -2
# vel  -2 -3
# vel  -2 -3
# vel  1 -5
# vel  -5 5
# vel  -1 3
# vel  -2 3
# vel  -1 2
# vel  0 1
# vel  -1 1
# vel  -1 0
# vel  -1 -1
# vel  -1 -1
# vel  6 -7
# vel  -2 -3
# vel  -1 -3
# vel  -1 -3
# vel  -3 3
# vel  -2 3
# vel  -1 2
# vel  -1 2
# vel  -1 1
# vel  -1 -1
# vel  -1 -1
# vel  7 6
# vel  3 -4
# vel  4 -5
# vel  -2 -3
# vel  -2 -3
# vel  -2 3
# vel  -1 3
# vel  -3 4
# vel  -2 2
# vel  -3 -5
# vel  -1 1
# vel  -4 -3
# vel  -4 5
# vel  -4 -1
# vel  -5 -3
# vel  -3 -5
# vel  -4 -5
# vel  -2 3
# vel  -4 3
# vel  -4 5
# vel  -4 4
# vel  -7 -3
# vel  -3 0
# vel  -2 -1
# vel  -3 -2
# vel  -3 -3
# vel  -3 -3
# vel  -5 -2
# vel  -4 5
# vel  -4 5
# vel  -7 1
# vel  -6 -1
# vel  -3 0
# vel  -3 -2
# vel  -4 -3
# vel  -3 -3
# vel  -7 2
# vel  -7 1
# vel  -7 1
# vel  -7 -2
# vel  -7 5
# ------------ Step 18 ---------
#  Image pair:
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00420.png
#    /Users/Ignacio/cellmodeller/data/Tutorial_1a-18-04-10-17-59/step-00410.png
# vel  5 5
# vel  5 5
# vel  5 -1
# vel  4 -1
# vel  4 -2
# vel  1 3
# vel  4 1
# vel  4 1
# vel  5 2
# vel  5 2
# vel  4 -2
# vel  4 -2
# vel  4 -2
# vel  3 3
# vel  3 4
# vel  1 2
# vel  3 1
# vel  5 2
# vel  5 1
# vel  3 -1
# vel  4 -2
# vel  3 -2
# vel  3 -4
# vel  2 4
# vel  4 5
# vel  3 3
# vel  0 3
# vel  2 1
# vel  2 1
# vel  2 -1
# vel  2 -1
# vel  2 -1
# vel  2 -2
# vel  4 -3
# vel  2 -4
# vel  2 4
# vel  4 4
# vel  0 4
# vel  2 -5
# vel  5 -6
# vel  2 0
# vel  1 0
# vel  1 -1
# vel  1 -1
# vel  1 -1
# vel  1 -4
# vel  1 -4
# vel  1 -4
# vel  1 4
# vel  2 4
# vel  -1 2
# vel  0 1
# vel  0 1
# vel  0 1
# vel  2 -4
# vel  -1 -7
# vel  1 -1
# vel  1 -4
# vel  0 -3
# vel  0 -5
# vel  2 -4
# vel  -1 4
# vel  -1 4
# vel  -1 2
# vel  -1 2
# vel  1 2
# vel  0 0
# vel  -2 -6
# vel  0 -1
# vel  0 0
# vel  0 -2
# vel  -1 -3
# vel  -1 -3
# vel  1 -4
# vel  -1 4
# vel  -2 4
# vel  -3 4
# vel  -7 5
# vel  0 2
# vel  -7 0
# vel  -2 0
# vel  -1 -1
# vel  -5 -7
# vel  6 -3
# vel  -1 -3
# vel  -1 -3
# vel  -1 -3
# vel  -2 4
# vel  -2 3
# vel  -1 2
# vel  -1 2
# vel  -1 7
# vel  -1 -1
# vel  0 -6
# vel  -2 2
# vel  -2 -2
# vel  -3 -4
# vel  1 -6
# vel  -2 -4
# vel  -2 3
# vel  -3 3
# vel  -1 5
# vel  -2 2
# vel  -3 1
# vel  -2 1
# vel  -2 -1
# vel  -6 6
# vel  -3 -3
# vel  -3 -4
# vel  -4 -5
# vel  -4 -5
# vel  -2 3
# vel  -4 3
# vel  -6 2
# vel  -6 2
# vel  -6 -4
# vel  -4 0
# vel  -2 0
# vel  -3 -3
# vel  -3 -3
# vel  -3 -3
# vel  -3 -4
# vel  -6 2
# vel  -6 2
# vel  -6 -1
# vel  -4 -1
# vel  -4 -1
# vel  -3 -3
# vel  -3 -3
# vel  -3 -3
# vel  -7 5
# vel  -6 -1
# vel  -6 -1
# vel  -7 -4
# vel  -6 -1
# Done

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16,8)
# %matplotlib notebook
pt.plotter(nframes,gridPV,gridstuff,velpos, imgs)
# Out:
# Results are ready, show plots? Yes will plot last frame and will include everything
# (1) Yes, (2) No, (3) Advanced: 1
# plotting.py:23: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if velpos == None:
# <img src="data:image/png;base64,..." width="1600">

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16,8)
# %matplotlib notebook
pt.plotter(nframes,gridEM,gridstuff,velpos, imgs)
# Out:
# Results are ready, show plots? Yes will plot last frame and will include everything
# (1) Yes, (2) No, (3) Advanced: 1
# <img src="data:image/png;base64,..." width="1600">

# %%
import numpy as np
deltagrid = np.zeros((nframes,gridstuff[0],gridstuff[1],5,2))
for frame in range(nframes):
    for ix in range(gridstuff[0]):
        for iy in range(gridstuff[1]):
            if gridPV[frame,ix,iy,2] != 0 and gridEM[frame,ix,iy,2] != 0: #Checks that both grids move to compare
                deltagrid[frame,ix,iy,0] = [gridPV[frame,ix,iy,0],gridEM[frame,ix,iy,0]]
                deltagrid[frame,ix,iy,1] = [gridPV[frame,ix,iy,1],gridEM[frame,ix,iy,1]]
                deltagrid[frame,ix,iy,2] = 1
                deltagrid[frame,ix,iy,3] = [gridPV[frame,ix,iy,3],gridEM[frame,ix,iy,3]]
                deltagrid[frame,ix,iy,4] = [gridPV[frame,ix,iy,4],gridEM[frame,ix,iy,4]]

# %%
plt.clf()

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16,8)
# %matplotlib notebook
for element in deltagrid:
    for ix in range(gridstuff[0]):
        for iy in range(gridstuff[1]):
            if deltagrid[frame,ix,iy,2,0] == 0:
                plt.plot(element[ix,iy,3,0]/element[ix,iy,3,1],element[ix,iy,4,0]/element[ix,iy,4,1],"ko", markersize = 0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1600">
# /Users/Ignacio/anaconda3/envs/cellmodeller/lib/python2.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# <div id='020cecca-d2aa-489f-8b09-0f3b743fe8bb'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-57761b4680e7> in <module>()
#       9         for iy in range(gridstuff[1]):
#      10             if deltagrid[frame,ix,iy,2,0] == 0:
# ---> 11                 plt.plot(element[ix,iy,3,0]/element[ix,iy,3,1],element[ix,iy,4,0]/element[ix,iy,4,1],"ko", markersize = 0.5)
#      12 plt.show()
#      13
#
# /Users/Ignacio/anaconda3/envs/cellmodeller/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# /Users/Ignacio/anaconda3/envs/cellmodeller/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Users/Ignacio/anaconda3/envs/cellmodeller/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1529             lines.append(line)
#    1530
# -> 1531         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1532         return lines
#    1533
#
# /Users/Ignacio/anaconda3/envs/cellmodeller/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in autoscale_view(self, tight, scalex, scaley)
#    2447         if self.use_sticky_edges and (self._xmargin or self._ymargin):
#    2448             stickies = [artist.sticky_edges for artist in self.get_children()]
# -> 2449             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2450             y_stickies = sum([sticky.y for sticky in stickies], [])
#    2451             if self.get_xscale().lower() == 'log':
#
# KeyboardInterrupt:

# %%
plt.show()
